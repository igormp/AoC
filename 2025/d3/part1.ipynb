# %%
import heapq
from collections import Counter

# %%
#FILE = "example.txt"
FILE = "input.txt"

# %%
inputs = [
    list(map(int, list(line.split()[0]))) for line in open(FILE)
]

# %%
inputs
# Out:
# [[3,
#   2,
#   2,
#   3,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   4,
#   2,
#   3,
#   3,
#   4,
#   2,
#   1,
#   3,
#   3,
#   3,
#   2,
#   1,
#   3,
#   2,
#   3,
#   3,
#   2,
#   1,
#   1,
#   3,
#   3,
#   3,
#   2,
#   5,
#   2,
#   2,
#   2,
#   2,
#   3,
#   3,
#   3,
#   4,
#   2,
#   3,
#   3,
#   2,
#   3,
#   2,
#   3,
#   3,
#   2,
#   3,
#   3,
#   4,
#   3,
#   7,
#   1,
#   3,
#   3,
#   3,
#   1,
#   3,
#   2,
#   1,
#   4,
#   3,
#   4,
#   2,
#   3,
#   1,
#   2,
#   3,
#   1,
#   2,
#   3,
#   2,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   2,
#   3,
#   2,
#   3,
#   3,
#   4,
#   2,
#   3,
#   3,
#   3,
#   2,
#   3,
#   3,
#   2,
#   2,
#   1,
#   2,
#   2],
#  [3,
#   4,
#   2,
#   2,
#   3,
#   2,
#   3,
#   1,
#   2,
#   3,
#   3,
#   4,
#   9,
#   1,
#   3,
#   4,
#   3,
#   3,
#   2,
#   4,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   4,
#   3,
#   2,
#   3,
#   3,
#   3,
#   3,
#   1,
#   3,
#   3,
#   3,
#   3,
#   3,
#   2,
# ...

# %%
total_output = 0
for line_no, i in enumerate(inputs):
    # for a in range(9,0,-1):
    #     if a not in i:
    #         continue
    a = max(i)
    while True:
        if a not in i:
            a -= 1
            continue
        # if i.count(a) > 1:
        #     output = int(f"{a}{a}")
        #     print(f"{line_no+1:3}: {output} i1: {i.index(a):2} i2: {i.index(a, i.index(a)+1):2} duplicated number")
        #     total_output += output
        #     break
        pos = i.index(a)
        if pos == len(i)-1:
            a -= 1
            print(f"{line_no+1:3}: {a} last element at {pos}, skipping...")
            continue
        b = max(i[pos+1:])
        output = int(f"{a}{b}")
        print(f"{line_no+1:3}: {output} i1: {i.index(a):2} i2: {i.index(b, pos+1):2}")
        if i.index(a) >= i.index(b, pos+1):
            print("@@@@@@@@@@@@@@@@")
        total_output += output
        break
# Out:
#   1: 74 i1: 55 i2: 64
#   2: 98 i1: 12 i2: 82
#   3: 88 i1: 84 i2: 94
#   4: 88 i1: 57 i2: 65
#   5: 99 i1:  7 i2: 30
#   6: 76 i1: 22 i2: 53
#   7: 55 i1: 28 i2: 70
#   8: 87 i1: 23 i2: 85
#   9: 54 i1: 59 i2: 64
#  10: 99 i1: 48 i2: 85
#  11: 87 i1: 13 i2: 62
#  12: 77 i1: 29 i2: 67
#  13: 98 i1: 10 i2: 16
#  14: 87 i1: 79 i2: 84
#  15: 98 i1: 79 i2: 94
#  16: 99 i1: 32 i2: 36
#  17: 88 i1: 42 i2: 90
#  18: 99 i1:  4 i2:  6
#  19: 87 i1: 55 i2: 73
#  20: 96 i1: 87 i2: 95
#  21: 83 i1: 86 i2: 87
#  22: 77 i1: 33 i2: 51
#  23: 98 i1: 15 i2: 20
#  24: 86 i1: 89 i2: 98
#  25: 75 i1: 13 i2: 24
#  26: 72 i1: 98 i2: 99
#  27: 77 i1: 23 i2: 86
#  28: 88 i1:  5 i2: 36
#  29: 87 i1: 47 i2: 60
#  30: 85 i1:  1 i2: 52
#  31: 65 i1:  9 i2: 29
#  32: 86 i1: 62 i2: 89
#  33: 66 i1: 33 i2: 36
#  34: 99 i1:  3 i2: 91
#  35: 86 i1: 42 i2: 49
#  36: 95 i1: 97 i2: 99
#  37: 99 i1: 57 i2: 75
#  38: 88 i1: 20 i2: 66
#  39: 87 i1:  1 i2:  2
#  40: 44 i1: 76 i2: 82
#  41: 66 i1:  0 i2:  9
# ...

# %%
total_output
# Out:
# 17207

# %% [markdown]
# 17206 is too low

# %%
# heap + counter strategy
# counts = Counter(i)
# positions = {}
# for idx, j in enumerate(i):
#     if j in positions:
#         heapq.heappush(positions[j], idx)
#     else:
#         positions[j] = [idx]
#         heapq.heapify(positions[j])
