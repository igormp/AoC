# %%
import heapq
from collections import Counter, defaultdict
from itertools import product
from math import prod
import numpy as np
from dataclasses import dataclass
from functools import lru_cache

# %%
#FILE = "example.txt"
FILE = "input.txt"

# %%
inputs = [
    line.rstrip('\n').split(' ') for line in open(FILE)
]

# %%
parsed_inputs = {
    input[0].strip(':'): set(input[1:])
    for input in inputs
}

# %%
parsed_inputs
# Out:
# {'the': {'aki', 'taq'},
#  'fnc': {'dvj', 'nhp', 'shq', 'ule'},
#  'eub': {'apo', 'pxs', 'you'},
#  'fde': {'out'},
#  'bsp': {'dvj', 'nhp', 'shq'},
#  'inu': {'nvm', 'pwf', 'qbu'},
#  'grs': {'iom'},
#  'ygp': {'ewb',
#   'hqf',
#   'irk',
#   'jbq',
#   'jnh',
#   'jou',
#   'kxa',
#   'mwz',
#   'pgo',
#   'tlh',
#   'uya',
#   'ykx'},
#  'rlk': {'qcl'},
#  'byn': {'vxi', 'wdb'},
#  'hfl': {'bti', 'kec', 'ulu'},
#  'vni': {'bbm'},
#  'hux': {'yqt'},
#  'xca': {'auz', 'hww', 'hzg'},
#  'rdq': {'plm'},
#  'sbb': {'zgs'},
#  'qlb': {'nvm', 'pez', 'pwf'},
#  'yil': {'dry', 'roo'},
#  'zzh': {'hoz', 'hvb'},
#  'doc': {'cvo', 'mwo', 'rlk'},
#  'gma': {'odi', 'tbq', 'xor', 'yxy'},
#  'pkq': {'grs', 'kqp', 'nco'},
#  'yqd': {'imp', 'jdu', 'qjy', 'xlc'},
#  'nbn': {'fft', 'hpp', 'jre', 'lcc'},
#  'xkq': {'lie', 'nwz'},
#  'zix': {'ktb', 'nsq'},
#  'iic': {'out'},
#  'jou': {'fyz', 'hmw', 'ijf', 'wev'},
#  'yon': {'efj', 'eub', 'nqq'},
#  'von': {'fft', 'jre'},
#  'otl': {'ekk'},
#  'dpy': {'oqa', 'xfn'},
#  'ggf': {'udo'},
#  'auz': {'ojm'},
#  'uvi': {'tye', 'yaa'},
#  'xlm': {'hsb', 'hwv', 'jxv', 'vig'},
#  'ceo': {'out'},
#  'gmz': {'ysa'},
#  'aki': {'psw', 'qfz', 'xlm', 'zzd'},
#  'ayo': {'dsd', 'ljt', 'ods'},
#  'kfy': {'vvf'},
#  'gmx': {'bbm', 'tbq', 'xor'},
#  'lgg': {'bqi', 'cjt', 'mmr', 'zmb'},
#  'rik': {'lgg', 'zfx', 'zxh'},
#  'mwz': {'oan', 'uxk'},
#  'gcl': {'tbq', 'xor'},
#  'jdu': {'cvv', 'jhx', 'ohv', 'tph'},
#  'dgc': {'nby', 'yfj'},
#  'tpp': {'flk', 'jse', 'kqi', 'ltl', 'nbr'},
#  'eas': {'zru', 'zto'},
#  'vzg': {'qxn', 'vch'},
#  'vyg': {'cui', 'cwf', 'rjf'},
#  'not': {'dow', 'rgp'},
#  'pez': {'hot'},
#  'rrs': {'psw', 'vkg', 'xlm', 'zzd'},
#  'lyp': {'cnt', 'szs', 'ysa'},
#  'zhz': {'kjo', 'srr'},
#  'hqz': {'out'},
#  'acd': {'aan'},
#  'jta': {'bbm', 'tbq', 'yxy'},
#  'jyj': {'apo', 'you'},
#  'fky': {'cgh'},
#  'ovt': {'jyr', 'lgs', 'pyu', 'sbb'},
#  'ujd': {'dub'},
#  'afe': {'cca', 'lgk'},
#  'qov': {'efj', 'kpf', 'nqq'},
#  'mlv': {'ase', 'pyu'},
#  'egj': {'grs', 'kqp', 'nco'},
#  'dry': {'hoz', 'icp', 'qxh'},
#  'nrs': {'imp', 'jdu', 'wnu', 'xlc'},
#  'lrb': {'tsr'},
#  'awh': {'oan', 'uxk', 'yek'},
#  'aik': {'ddr', 'dlu', 'pvm', 'vzh'},
#  'vgk': {'jyr', 'lgs', 'sbb'},
#  'bql': {'gxf', 'wmh'},
#  'vya': {'hvo', 'jee', 'yzt'},
#  'ods': {'cca', 'oru'},
#  'bqi': {'bob',
#   'bql',
#   'eas',
#   'eeb',
#   'fog',
#   'hhw',
#   'inu',
#   'kjz',
#   'kly',
#   'otl',
#   'qiq',
#   'tbe',
#   'tsk',
#   'upy',
#   'yrw'},
#  'yaa': {'apo', 'pxs', 'you'},
#  'wev': {'ajb', 'cgr', 'swl'},
#  'jhx': {'out'},
#  'yql': {'osp'},
#  'wdb': {'rik'},
#  'uld': {'bqi', 'cjt', 'mmr', 'zmb'},
#  'cwx': {'krg'},
#  'ozg': {'lgg', 'zfx', 'zxh'},
#  'irw': {'auz', 'yil'},
#  'tqq': {'bse', 'duk', 'ihh'},
#  'tem': {'qnr', 'zbg'},
#  'hqf': {'now', 'ovt', 'vgk'},
#  'mwo': {'yay', 'zja'},
#  'nxp': {'oqa', 'xfn'},
#  'msx': {'fnd', 'ipy', 'twi', 'zut'},
#  'qqs': {'cjt', 'mmr'},
#  'hpp': {'uld', 'zqb'},
#  'cws': {'dtt', 'nap', 'plm', 'vvf'},
#  'yfj': {'out'},
#  'cjd': {'aik', 'hua', 'lva'},
#  'ytc': {'aik', 'lva'},
#  'uuj': {'gcl'},
#  'lpr': {'out'},
#  'dac': {'kns', 'onr', 'wxe'},
#  'bse': {'rlk'},
#  'ffh': {'qir', 'the'},
#  'jmj': {'tye', 'yaa'},
#  'aiq': {'cca', 'euo', 'oru', 'qrc'},
#  'mrk': {'cnt'},
#  'hva': {'jke'},
#  'onr': {'hqq'},
#  'hro': {'czj', 'jta', 'zsg'},
#  'hbf': {'vxi', 'wdb'},
#  'ash': {'qxh'},
#  'wmg': {'cki', 'dub', 'ybp'},
#  'uya': {'aay', 'gsj', 'mii', 'sse'},
#  'xjp': {'hoz', 'hvb', 'qxh'},
#  'dec': {'efj', 'eub', 'kpf', 'nqq'},
#  'bob': {'esf', 'zbg', 'zhz'},
#  'cgh': {'pxs', 'you'},
#  'ibt': {'acw', 'nhy', 'pdw', 'wns'},
#  'cgr': {'odi', 'yxy'},
#  'cfr': {'dow', 'hwz', 'pgb', 'rgp'},
#  'dmn': {'czj', 'zsg'},
#  'cjj': {'hux', 'itm'},
#  'vig': {'hoz', 'hvb', 'icp'},
#  'wpr': {'dmn', 'fss', 'hro', 'zro'},
#  'nhy': {'jqz', 'utf', 'vib', 'ysb'},
#  'icp': {'bsp',
#   'bvy',
#   'dfy',
#   'dpy',
#   'egj',
#   'eyn',
#   'fnc',
#   'hap',
#   'icl',
#   'mml',
#   'nek',
#   'nth',
#   'nxp',
#   'oou',
#   'pkq',
#   'qcz',
#   'tpp',
#   'ufo',
#   'wal',
#   'xce',
#   'xfk'},
#  'tfm': {'bqi', 'cjt'},
#  'bqf': {'inr', 'lie', 'nwz'},
#  'vkg': {'hsb'},
#  'kec': {'kqa', 'qqc', 'ryp', 'yxx'},
#  'jse': {'hva', 'lkq', 'nct', 'vya', 'ypf'},
#  'szs': {'zgn'},
#  'ljt': {'cca', 'lgk', 'qrc'},
#  'you': {'cjd', 'ijc', 'iwp', 'mdr', 'yoa'},
#  'mmr': {'bhj',
#   'bql',
#   'eeb',
#   'fek',
#   'ffh',
#   'fog',
#   'hhw',
#   'inu',
#   'kjz',
#   'kly',
#   'otl',
#   'qiq',
#   'tem',
#   'tsk',
#   'upy',
#   'yrw'},
#  'yic': {'acd', 'ajh', 'dhw'},
#  'tgc': {'hhq'},
#  'kns': {'pxs'},
#  'cki': {'ctf', 'gil', 'voe', 'wgb'},
#  'qcl': {'out'},
#  'zfb': {'kpl', 'tdr', 'twx'},
#  'hvo': {'lgk', 'oru', 'qrc'},
#  'pdw': {'jqz', 'mia', 'ysb'},
#  'wns': {'mia', 'utf', 'vib', 'ysb'},
#  'ocv': {'cca', 'euo', 'lgk', 'oru', 'qrc'},
#  'iqu': {'dac', 'uvi', 'uwo', 'waf'},
#  'esf': {'kjo', 'srr', 'wij'},
#  'icg': {'bfv', 'egf', 'nja', 'xcs'},
#  'roo': {'hoz', 'hvb', 'icp'},
#  'qxn': {'kia'},
#  'fss': {'czj'},
#  'odi': {'byn',
#   'cfr',
#   'ebr',
#   'ehh',
#   'ghx',
#   'gmz',
#   'hbf',
#   'iuo',
#   'ldm',
#   'lyp',
#   'mrk',
#   'nbn',
#   'not',
#   'pnj',
#   'pot',
#   'qtw',
#   'uiv',
#   'vea',
#   'von',
#   'zca',
#   'zix'},
#  'kjo': {'kkr', 'ltf'},
#  'dlu': {'nja', 'xcs'},
#  'vvb': {'cca'},
#  'qfz': {'jxv'},
#  'wdr': {'dac', 'jmj', 'uwo'},
#  'qjy': {'cvv'},
#  'kly': {'zto'},
#  'peu': {'out'},
#  'yek': {'iih', 'luy', 'mei'},
#  'qxh': {'bsp', 'eyn', 'nth', 'oou', 'tpp', 'ufo', 'xce'},
#  'pln': {'obi', 'pfu'},
#  'bip': {'ist', 'vxi', 'wdb'},
#  'rno': {'fhx', 'imo'},
#  'sls': {'pyd', 'qxn', 'ztw'},
#  'iyp': {'dxi', 'mpn', 'wef'},
#  'dtt': {'alv', 'ido', 'peu', 'sce'},
#  'qud': {'bse', 'doc', 'duk', 'ihh'},
#  'wgb': {'cca', 'euo', 'oru', 'qrc'},
#  'kqi': {'hva', 'lkq', 'vya'},
#  'qbu': {'irw', 'xca'},
#  'ybp': {'ctf', 'voe', 'wgb'},
#  'mxm': {'bqi'},
#  'zto': {'ash', 'gom', 'nzo'},
#  'ums': {'cca', 'lgk', 'oru', 'qrc'},
#  'eax': {'fnd', 'ipy'},
#  'vxi': {'rik', 'vfg'},
#  'mii': {'eax', 'fgi', 'rxs'},
#  'dzs': {'bse', 'duk', 'ihh'},
#  'fhf': {'apo', 'you'},
#  'yxy': {'cfr', 'gmz', 'pot', 'tys', 'von'},
#  'iuo': {'wjp'},
#  'lfj': {'euo', 'lgk', 'qrc'},
#  'adg': {'hua', 'lva'},
#  'uco': {'bti', 'kec', 'ulu'},
#  'oru': {'cfw',
#   'dju',
#   'dzk',
#   'jbn',
#   'lrb',
#   'ofr',
#   'qbg',
#   'vhw',
#   'vyg',
#   'xgh',
#   'yap',
#   'yic'},
#  'agf': {'dec', 'drd'},
#  'dvj': {'rsh', 'ujd'},
#  'now': {'jyr', 'pyu', 'sbb'},
#  'hli': {'cjj', 'omy', 'uul'},
#  'tve': {'xor', 'yxy'},
#  'osp': {'arf', 'btr', 'xjp'},
#  'lnv': {'bbm', 'odi', 'tbq', 'xor'},
#  'twx': {'tfm', 'xtt'},
#  'xgh': {'bxi', 'iqu', 'wdr'},
#  'hhv': {'jdu', 'wnu', 'xlc'},
#  'aan': {'cgh', 'rhm'},
#  'hzg': {'rol'},
#  'eeb': {'bcj', 'zto'},
#  'ajs': {'awh', 'ewb', 'ibc', 'irk', 'jou', 'kxa', 'tlh', 'uya'},
#  'acw': {'jqz', 'ysb'},
#  'zbx': {'xts'},
#  'efj': {'apo', 'pxs', 'you'},
#  'ewb': {'fyz', 'hmw', 'wev'},
#  'mml': {'jse', 'kqi', 'ltl', 'nbr'},
#  'mdd': {'nsq'},
#  'vuc': {'hqz', 'jbd'},
#  'nbr': {'hva', 'lkq', 'vya'},
#  'aay': {'eax', 'ewy', 'fgi', 'msx'},
#  'ypf': {'hvo', 'yzt'},
#  'cfw': {'agf'},
#  'fyz': {'cgr', 'gcl', 'swl'},
#  'nzo': {'hoz'},
#  'ltf': {'arf', 'btr', 'nwy'},
#  'dxi': {'dzs', 'qud', 'tqq', 'unb'},
#  'hcx': {'bti', 'kec'},
#  'tod': {'bqi', 'cjt'},
#  'bbm': {'cfr', 'gmz', 'hbf', 'iuo', 'mdd', 'not', 'qtw', 'tys'},
#  'kvd': {'hyl', 'nab', 'qqs', 'rig'},
#  'bti': {'kqa', 'lex', 'qqc', 'ryp', 'yxx'},
#  'zut': {'gmx', 'lnv', 'pff'},
#  'ykx': {'ijf', 'uuj', 'wev'},
#  'xwt': {'apo', 'you'},
#  'nco': {'aar', 'ayo', 'iom'},
#  'qnr': {'kjo', 'yql'},
#  'jcm': {'cgh', 'djk', 'rhm'},
#  'ton': {'yfj'},
#  'cwf': {'dec', 'drd', 'qov', 'tks', 'yon'},
#  'oqa': {'hfl', 'uco'},
#  'kzb': {'rsh', 'wmg'},
#  'apo': {'adg',
#   'bhg',
#   'cjd',
#   'cwx',
#   'ijc',
#   'iyp',
#   'kmi',
#   'llk',
#   'mdr',
#   'pom',
#   'qea',
#   'sls',
#   'vzg'},
#  'mhf': {'pto', 'rxe', 'tve'},
#  'lex': {'euo', 'oru', 'qrc'},
#  'krg': {'lie'},
#  'tbq': {'byn',
#   'cfr',
#   'ebr',
#   'ehh',
#   'hbf',
#   'iuo',
#   'lyp',
#   'mdd',
#   'mrk',
#   'nbn',
#   'not',
#   'pnj',
#   'pot',
#   'tys',
#   'vea',
#   'von',
#   'zca',
#   'zix'},
#  'djk': {'apo', 'you'},
#  'hhw': {'bzb', 'ekk', 'tqn'},
#  'fti': {'ysb'},
#  'hsb': {'qxh'},
#  'kpf': {'apo'},
#  'luy': {'dmg', 'jco'},
#  'qiq': {'gxf', 'ldl', 'sai', 'wmh'},
#  'ajh': {'fky', 'jcm', 'olo', 'xpf'},
#  'pnj': {'cnt', 'szs'},
#  'wxe': {'apo', 'you'},
#  'fnd': {'dsj', 'gmx', 'pff'},
#  'egf': {'udr', 'wdi'},
#  'pmo': {'ocv', 'xtr'},
#  'wjp': {'hyl', 'nab', 'qqs', 'rig'},
#  'btr': {'hvb', 'icp'},
#  'mdr': {'aik', 'lva'},
#  'jco': {'pto', 'tve'},
#  'eyn': {'vow', 'wll', 'yvx'},
#  'wdi': {'ceo', 'nby', 'yfj'},
#  'udr': {'ceo', 'yfj'},
#  'jnh': {'mlv', 'now', 'vgk'},
#  'llk': {'bqf'},
#  'flk': {'hva', 'lkq', 'nct', 'vya'},
#  'xts': {'wdo'},
#  'pgo': {'elm', 'fss', 'hro'},
#  'wdo': {'dtb'},
#  'dfy': {'grs', 'kqp'},
#  'frs': {'arm', 'boq'},
#  'yap': {'bxi', 'iqu', 'vkn', 'wdr'},
#  'voe': {'cca', 'euo', 'lgk', 'qrc'},
#  'pgb': {'ixd', 'mkb', 'mxm', 'ruj'},
#  'ase': {'uow', 'vni', 'zgs'},
#  'imp': {'cvv', 'jhx', 'lpr', 'tph'},
#  'ryp': {'lgk', 'qrc'},
#  'kqa': {'cca', 'euo', 'lgk', 'oru', 'qrc'},
#  'tye': {'pxs'},
#  'jre': {'toc', 'uld'},
#  'zzd': {'hwv', 'vig'},
#  'tks': {'efj', 'eub', 'nqq'},
#  'jxv': {'hoz'},
#  'zro': {'jta'},
#  'rol': {'hvb', 'icp', 'qxh'},
#  'qir': {'aki', 'mpr', 'rrs', 'taq'},
#  'rgp': {'mxm', 'yhw'},
#  'ehh': {'ttx'},
#  'fek': {'ldl', 'orh', 'sai', 'wmh'},
#  'duk': {'cvo', 'rlk', 'zhh'},
#  'cvv': {'out'},
#  'szj': {'dqh', 'onw', 'pmo', 'qop', 'syt'},
#  'hua': {'ddr', 'dlu', 'icg', 'pvm'},
#  'lgk': {'bjx', 'dzk', 'jbn', 'vhw'},
#  'idw': {'dqh', 'onw', 'pmo', 'syt'},
#  'gsj': {'eax', 'ewy', 'fgi', 'rxs'},
#  'elm': {'gma'},
#  'xfk': {'egz', 'wll', 'yvx'},
#  'irk': {'sse'},
#  'xtt': {'zmb'},
#  'ldm': {'dow', 'pgb', 'rgp', 'wyq'},
#  'jbd': {'out'},
#  'vro': {'cca', 'euo', 'oru', 'qrc'},
#  'shq': {'ujd'},
#  'jke': {'cca', 'euo', 'lgk', 'oru', 'qrc'},
#  'hoz': {'bsp',
#   'bvy',
#   'egj',
#   'fnc',
#   'hap',
#   'icl',
#   'mml',
#   'nek',
#   'nxp',
#   'pkq',
#   'qcz',
#   'tpp',
#   'ufo',
#   'wal',
#   'xce',
#   'xfk'},
#  'jqz': {'nrs', 'yqd'},
#  'zgs': {'bbm', 'odi', 'yxy'},
#  'xcs': {'wdi'},
#  'fft': {'uld', 'xfg'},
#  'aqf': {'cke', 'wjh'},
#  'srr': {'kkr', 'ltf', 'osp'},
#  'gue': {'pln', 'tgc', 'wjh'},
#  'nby': {'out'},
#  'fgi': {'twi', 'zut'},
#  'zgn': {'cjt', 'mmr', 'zmb'},
#  'ido': {'out'},
#  'nth': {'idw', 'szj'},
#  'byx': {'rjp', 'tdi'},
#  'dtb': {'hqq', 'pxs'},
#  'rsh': {'dub'},
#  'ldl': {'bmw', 'dvu', 'gio'},
#  'yxx': {'lgk'},
#  'zsg': {'bbm', 'odi', 'tbq', 'yxy'},
#  'ysa': {'rrz', 'tod', 'zgn'},
#  'iih': {'dmg'},
#  'yvx': {'afe', 'aiq', 'lfj', 'ums', 'vro'},
#  'qac': {'dqh', 'onw', 'pmo', 'qop', 'syt'},
#  'ofr': {'agf', 'cui', 'rjf'},
#  'cnt': {'rrz'},
#  'pnn': {'byi', 'oan', 'uxk', 'yek'},
#  'iom': {'dsd', 'ljt', 'ods'},
#  'nct': {'hvo', 'jke', 'yzt'},
#  'ufo': {'oqa', 'uyo', 'xfn'},
#  'wjh': {'obi', 'pfu'},
#  'ojm': {'hvb', 'icp', 'qxh'},
#  'fhx': {'boq', 'iic'},
#  'nap': {'alv', 'fde', 'sce'},
#  'ipy': {'dsj', 'gmx', 'lnv'},
#  'hhg': {'awh',
#   'hqf',
#   'ibc',
#   'irk',
#   'jbq',
#   'jnh',
#   'kxa',
#   'mwz',
#   'pnn',
#   'tlh',
#   'uya',
#   'ykx'},
#  'jbq': {'mlv', 'now', 'vgk'},
#  'qrc': {'dju',
#   'hli',
#   'lrb',
#   'ofr',
#   'pjp',
#   'qbg',
#   'snw',
#   'tmv',
#   'vhw',
#   'vyg',
#   'xgh',
#   'yap',
#   'yic'},
#  'hqq': {'cwx', 'fbo', 'ibt', 'iwp', 'iyp', 'mdr', 'sls', 'vzg', 'xbq'},
#  'svx': {'apo', 'hqq', 'you'},
#  'uxk': {'iih', 'luy', 'mei', 'vvq'},
#  'iwp': {'fti', 'nhy', 'pdw', 'wns'},
#  'wrc': {'mhf'},
#  'dsj': {'bbm', 'tbq', 'xor', 'yxy'},
#  'nsq': {'ggf', 'kpl'},
#  'lva': {'ddr', 'dlu', 'icg', 'pvm', 'vzh'},
#  'nek': {'kzb', 'nhp', 'ule'},
#  'zqb': {'bqi', 'cjt', 'zmb'},
#  'ctf': {'euo', 'lgk', 'oru', 'qrc'},
#  'gle': {'hqq', 'pxs'},
#  'kpl': {'tfm', 'udo', 'xtt'},
#  'syt': {'ocv'},
#  'kmi': {'pyd', 'vch'},
#  'psw': {'dpb', 'hwv', 'vig'},
#  'nwy': {'hvb', 'icp', 'qxh'},
#  'tlh': {'fss', 'hro', 'zro'},
#  'wnf': {'dtt', 'vvf'},
#  'udo': {'bqi', 'cjt', 'mmr', 'zmb'},
#  'tbe': {'gxf', 'ldl', 'sai'},
#  'ruj': {'bqi'},
#  'twi': {'dsj', 'lnv', 'pff'},
#  'ysb': {'hhv', 'nrs', 'yqd'},
#  'ndx': {'ami'},
#  'ewy': {'fnd'},
#  'ibc': {'aay', 'mii'},
#  'dqh': {'xtr'},
#  'alv': {'out'},
#  'xce': {'qac'},
#  'qwl': {'hoz'},
#  'xtr': {'cca', 'euo', 'lgk', 'oru', 'qrc'},
#  'rhm': {'hqq', 'you'},
#  'cvo': {'jbd', 'qcl', 'yay', 'zja'},
#  'jbn': {'aqf'},
#  'ghx': {'kvd', 'ttx', 'wjp'},
#  'orh': {'bmw', 'dvu', 'gio', 'qxl', 'zzh'},
#  'tqn': {'rrs'},
#  'bhj': {'nvm', 'pwf', 'qbu'},
#  'itm': {'vys', 'xwt', 'yqt'},
#  'yhw': {'mmr'},
#  'czj': {'bbm', 'odi', 'xor', 'yxy'},
#  'jyr': {'uow', 'vni', 'zgs'},
#  'jfw': {'hqq', 'you'},
#  'vvq': {'dmg', 'mhf'},
#  'tph': {'out'},
#  'euo': {'dzk', 'snw', 'vyg', 'zbx'},
#  'mei': {'dmg', 'jco', 'mhf'},
#  'zmb': {'bhj',
#   'bob',
#   'bql',
#   'hhw',
#   'kjz',
#   'otl',
#   'qiq',
#   'qlb',
#   'tbe',
#   'tem',
#   'upy',
#   'yrw'},
#  'tsr': {'fky', 'jcm', 'xpf'},
#  'nqq': {'apo', 'hqq'},
#  'ijf': {'ajb', 'swl'},
#  'rig': {'bqi'},
#  'bcj': {'ash', 'rii'},
#  'wll': {'lfj'},
#  'dzk': {'omy', 'uul'},
#  'nja': {'dgc', 'ton', 'wdi'},
#  'dsd': {'cca', 'euo', 'lgk', 'oru', 'qrc'},
#  'qea': {'dxi', 'vdc', 'wef'},
#  'zja': {'out'},
#  'jee': {'cca', 'euo', 'oru', 'qrc'},
#  'dow': {'ixd', 'mkb', 'mxm', 'ruj'},
#  'uow': {'bbm', 'tbq', 'xor', 'yxy'},
#  'uul': {'itm'},
#  'wmh': {'bmw', 'dvu', 'qxl', 'zzh'},
#  'tdi': {'frs', 'imo', 'ndx'},
#  'bzb': {'aki', 'rrs', 'taq'},
#  'oan': {'iih', 'luy', 'wrc'},
#  'mkb': {'mmr', 'zmb'},
#  'swl': {'bbm', 'odi', 'xor'},
#  'zca': {'nsq'},
#  'taq': {'xlm', 'zzd'},
#  'omy': {'itm'},
#  'kqp': {'ayo'},
#  'kji': {'awh',
#   'ewb',
#   'hqf',
#   'irk',
#   'jou',
#   'kxa',
#   'mwz',
#   'pgo',
#   'pnn',
#   'tlh',
#   'uya',
#   'wpr',
#   'ykx'},
#  'yqt': {'hqq', 'pxs', 'you'},
#  'kjz': {'gxf', 'ldl', 'sai', 'wmh'},
#  'uwo': {'kns', 'onr', 'wxe'},
#  'nhp': {'ujd'},
#  'pyd': {'byx', 'kia'},
#  'upy': {'bcj', 'zto'},
#  'obi': {'fhf', 'gle', 'jyj', 'kzv'},
#  'ltl': {'ypf'},
#  'dpb': {'hoz', 'qxh'},
#  'pff': {'bbm', 'tbq', 'yxy'},
#  'bfv': {'dgc', 'sza', 'udr', 'wdi'},
#  'arf': {'hoz', 'qxh'},
#  'svr': {'ajs', 'hhg', 'kji', 'ygp', 'zdb'},
#  'vzh': {'tkr'},
#  'ktb': {'kpl', 'tdr', 'twx'},
#  'ulu': {'kqa', 'qqc', 'yxx'},
#  'kkr': {'nwy', 'xjp'},
#  'pfu': {'fhf', 'jfw', 'jyj'},
#  'xfn': {'uco'},
#  'oou': {'idw'},
#  'gom': {'hoz', 'hvb'},
#  'vow': {'aiq', 'ums'},
#  'ohv': {'out'},
#  'ttx': {'qqs', 'rig', 'xys'},
#  'fbo': {'pyd', 'qxn', 'vch', 'ztw'},
#  'cui': {'dec', 'drd', 'qov', 'tks'},
#  'yoa': {'xkq'},
#  'nab': {'cjt', 'zmb'},
#  'mpn': {'tqq'},
#  'inr': {'rdq', 'wnf'},
#  'drd': {'efj', 'eub'},
#  'fog': {'qnr', 'zbg', 'zhz'},
#  'cjt': {'bhj',
#   'bob',
#   'bql',
#   'eas',
#   'fek',
#   'ffh',
#   'inu',
#   'kly',
#   'otl',
#   'qiq',
#   'qlb',
#   'tbe',
#   'tem',
#   'tsk',
#   'upy',
#   'yrw'},
#  'ixd': {'bqi', 'cjt', 'mmr'},
#  'arm': {'out'},
#  'uiq': {'rjp', 'tdi'},
#  'sce': {'out'},
#  'wal': {'idw', 'qac', 'szj'},
#  'vfg': {'lgg', 'zxh'},
#  'olo': {'cgh', 'djk', 'rhm', 'svx'},
#  'waf': {'kns', 'tye'},
#  'dhw': {'fky', 'xpf'},
#  'ist': {'ozg', 'vfg'},
#  'bvy': {'flk', 'kqi'},
#  'gxf': {'bmw'},
#  'hww': {'dry', 'ojm', 'qwl', 'roo'},
#  'vys': {'you'},
#  'imo': {'ami', 'boq', 'ftg', 'iic'},
#  'vhw': {'cui', 'rjf'},
#  'hwv': {'icp', 'qxh'},
#  'xor': {'bip',
#   'byn',
#   'cfr',
#   'ebr',
#   'ehh',
#   'ghx',
#   'lyp',
#   'mrk',
#   'nbn',
#   'not',
#   'pnj',
#   'qtw',
#   'tys',
#   'uiv',
#   'vea',
#   'von',
#   'zix'},
#  'qqc': {'cca', 'euo', 'lgk', 'oru'},
#  'vea': {'kvd'},
#  'zbg': {'kjo', 'yql'},
#  'zhh': {'hqz'},
#  'kzv': {'hqq', 'pxs', 'you'},
#  'lcc': {'toc', 'uld', 'xfg'},
#  'rii': {'hoz', 'icp', 'qxh'},
#  'plm': {'alv', 'peu', 'sce'},
#  'hmw': {'cgr', 'gcl', 'swl'},
#  'rxs': {'ipy', 'twi'},
#  'kxa': {'itj'},
#  'wyq': {'ixd'},
#  'lgs': {'uow', 'vni'},
#  'rrz': {'zmb'},
#  'dmg': {'rxe', 'tve'},
#  'tkr': {'dgc', 'sza', 'ton'},
#  'pom': {'bqf', 'krg'},
#  'uyo': {'hcx', 'hfl', 'uco'},
#  'ami': {'out'},
#  'hap': {'idw', 'szj'},
#  'vvf': {'alv', 'fde', 'ido'},
#  'xys': {'bqi', 'cjt', 'mmr'},
#  'qbg': {'gue', 'wux'},
#  'mpr': {'psw', 'qfz', 'vkg', 'xlm'},
#  'qtw': {'ist', 'vxi', 'wdb'},
#  'zru': {'ash', 'gom'},
#  'yay': {'out'},
#  'sse': {'eax', 'ewy', 'msx', 'rxs'},
#  'hhq': {'gle'},
#  'pjp': {'agf'},
#  'wef': {'dzs', 'tqq', 'unb'},
#  'wnu': {'jhx', 'ohv', 'tph'},
#  'hvb': {'dfy', 'dpy', 'icl', 'nek', 'xfk'},
#  'ijc': {'aik', 'hua'},
#  'nwz': {'cws', 'kfy', 'rdq'},
#  'pyu': {'vni'},
#  'unb': {'bse', 'ihh'},
#  'toc': {'cjt', 'mmr'},
#  'ymz': {'hux', 'itm', 'vuf', 'wdo'},
#  'boq': {'out'},
#  'tsk': {'qir'},
#  'wux': {'cke', 'pln', 'tgc', 'wjh'},
#  'uhi': {'cki', 'ybp'},
#  'xbq': {'nhy'},
#  'ctt': {'hww', 'ryh'},
#  'egz': {'afe', 'vro'},
#  'gil': {'cca', 'euo', 'oru', 'qrc'},
#  'ddr': {'bfv', 'nja', 'tkr', 'xcs'},
#  'vch': {'kia', 'uiq'},
#  'rjf': {'dec', 'qov'},
#  'ekk': {'aki', 'mpr', 'rrs'},
#  'pxs': {'bhg',
#   'bkx',
#   'ibt',
#   'ijc',
#   'iwp',
#   'llk',
#   'mdr',
#   'pom',
#   'qea',
#   'sls',
#   'vzg',
#   'xbq',
#   'yoa',
#   'ytc'},
#  'aar': {'dsd', 'ods'},
#  'itj': {'ase', 'lgs'},
#  'yzt': {'euo', 'oru', 'qrc'},
#  'ryh': {'dry'},
#  'bjx': {'ajh'},
#  'kia': {'rjp', 'rno', 'tdi'},
#  'ule': {'uhi'},
#  'mia': {'nrs', 'yqd'},
#  'ebr': {'hwz', 'wyq'},
#  'pot': {'dow', 'hwz', 'pgb', 'rgp'},
#  'zxh': {'cjt'},
#  'bxi': {'uvi'},
#  'zdb': {'ewb', 'irk', 'jbq', 'jnh', 'kxa', 'pgo', 'tlh', 'uya', 'wpr', 'ykx'},
#  'cke': {'obi', 'pfu'},
#  'utf': {'yqd'},
#  'bkx': {'pyd', 'qxn', 'vch', 'ztw'},
#  'ztw': {'kia', 'uiq'},
#  'bhg': {'dxi', 'wef'},
#  'vib': {'yqd'},
#  'hyl': {'bqi', 'cjt', 'mmr', 'zmb'},
#  'xpf': {'cgh', 'djk', 'rhm', 'svx'},
#  'xlc': {'cvv', 'ohv', 'tph'},
#  'pwf': {'ctt', 'irw', 'xca'},
#  'vuf': {'xwt'},
#  'tmv': {'aqf', 'gue', 'wux'},
#  'rjp': {'fhx', 'imo', 'ndx'},
#  'ihh': {'cvo', 'mwo', 'vuc', 'zhh'},
#  'byi': {'iih', 'luy', 'vvq', 'wrc'},
#  'yrw': {'ekk', 'qir', 'tqn'},
#  'zfx': {'mmr'},
#  'lkq': {'jee', 'jke', 'yzt'},
#  'sai': {'bmw', 'dvu', 'gio', 'zzh'},
#  'uiv': {'lcc'},
#  'hwz': {'ixd', 'mkb', 'yhw'},
#  'rxe': {'odi', 'tbq', 'xor', 'yxy'},
#  'snw': {'cjj', 'omy', 'uul', 'xts', 'ymz'},
#  'ajb': {'bbm', 'tbq'},
#  'icl': {'kqp'},
#  'bmw': {'hoz', 'icp', 'qxh'},
#  'qop': {'vvb', 'xtr'},
#  'pto': {'bbm', 'odi', 'xor'},
#  'pvm': {'egf', 'xcs'},
#  'xfg': {'cjt', 'mmr', 'zmb'},
#  'cca': {'bjx',
#   'cfw',
#   'dju',
#   'dzk',
#   'hli',
#   'jbn',
#   'lrb',
#   'ofr',
#   'snw',
#   'tmv',
#   'xgh',
#   'yap',
#   'yic'},
#  'gio': {'hoz', 'qxh'},
#  'tys': {'ktb', 'zfb'},
#  'sza': {'ceo'},
#  'dub': {'voe', 'wgb'},
#  'tdr': {'udo'},
#  'qcz': {'egz', 'vow', 'wll'},
#  'hot': {'hww', 'hzg', 'ryh', 'yil'},
#  'onw': {'ocv', 'vvb', 'xtr'},
#  'dju': {'vkn'},
#  'wij': {'osp'},
#  'vdc': {'dzs', 'qud', 'unb'},
#  'nvm': {'ctt', 'hot', 'irw', 'xca'},
#  'vkn': {'dac', 'jmj', 'uwo'},
#  'ftg': {'out'},
#  'lie': {'cws', 'kfy', 'rdq'},
#  'qxl': {'icp'},
#  'dvu': {'hvb', 'icp', 'qxh'}}

# %%
inverted_index = defaultdict(set)
for k, v in parsed_inputs.items():
    for v_item in v:
        inverted_index[v_item].add(k)

# %%
inverted_index
# Out:
# defaultdict(set,
#             {'aki': {'bzb', 'ekk', 'qir', 'the'},
#              'taq': {'bzb', 'qir', 'the'},
#              'nhp': {'bsp', 'fnc', 'nek'},
#              'shq': {'bsp', 'fnc'},
#              'dvj': {'bsp', 'fnc'},
#              'ule': {'fnc', 'nek'},
#              'pxs': {'cgh',
#               'dtb',
#               'efj',
#               'eub',
#               'gle',
#               'kns',
#               'kzv',
#               'tye',
#               'yaa',
#               'yqt'},
#              'apo': {'djk',
#               'efj',
#               'eub',
#               'fhf',
#               'jyj',
#               'kpf',
#               'nqq',
#               'svx',
#               'wxe',
#               'xwt',
#               'yaa'},
#              'you': {'cgh',
#               'djk',
#               'efj',
#               'eub',
#               'fhf',
#               'jfw',
#               'jyj',
#               'kzv',
#               'rhm',
#               'svx',
#               'vys',
#               'wxe',
#               'xwt',
#               'yaa',
#               'yqt'},
#              'out': {'alv',
#               'ami',
#               'arm',
#               'boq',
#               'ceo',
#               'cvv',
#               'fde',
#               'ftg',
#               'hqz',
#               'ido',
#               'iic',
#               'jbd',
#               'jhx',
#               'lpr',
#               'nby',
#               'ohv',
#               'peu',
#               'qcl',
#               'sce',
#               'tph',
#               'yay',
#               'yfj',
#               'zja'},
#              'pwf': {'bhj', 'inu', 'qlb'},
#              'qbu': {'bhj', 'inu'},
#              'nvm': {'bhj', 'inu', 'qlb'},
#              'iom': {'grs', 'nco'},
#              'mwz': {'hhg', 'kji', 'ygp'},
#              'jbq': {'hhg', 'ygp', 'zdb'},
#              'jnh': {'hhg', 'ygp', 'zdb'},
#              'jou': {'ajs', 'kji', 'ygp'},
#              'irk': {'ajs', 'hhg', 'kji', 'ygp', 'zdb'},
#              'uya': {'ajs', 'hhg', 'kji', 'ygp', 'zdb'},
#              'ykx': {'hhg', 'kji', 'ygp', 'zdb'},
#              'pgo': {'kji', 'ygp', 'zdb'},
#              'kxa': {'ajs', 'hhg', 'kji', 'ygp', 'zdb'},
#              'hqf': {'hhg', 'kji', 'ygp'},
#              'tlh': {'ajs', 'hhg', 'kji', 'ygp', 'zdb'},
#              'ewb': {'ajs', 'kji', 'ygp', 'zdb'},
#              'qcl': {'cvo', 'rlk'},
#              'wdb': {'bip', 'byn', 'hbf', 'qtw'},
#              'vxi': {'bip', 'byn', 'hbf', 'qtw'},
#              'bti': {'hcx', 'hfl', 'uco'},
#              'kec': {'hcx', 'hfl', 'uco'},
#              'ulu': {'hfl', 'uco'},
#              'bbm': {'ajb',
#               'czj',
#               'dsj',
#               'gmx',
#               'jta',
#               'lnv',
#               'pff',
#               'pto',
#               'swl',
#               'uow',
#               'vni',
#               'zgs',
#               'zsg'},
#              'yqt': {'hux', 'itm'},
#              'auz': {'irw', 'xca'},
#              'hww': {'ctt', 'hot', 'xca'},
#              'hzg': {'hot', 'xca'},
#              'plm': {'cws', 'rdq'},
#              'zgs': {'ase', 'jyr', 'sbb'},
#              'pez': {'qlb'},
#              'dry': {'hww', 'ryh', 'yil'},
#              'roo': {'hww', 'yil'},
#              'hvb': {'btr',
#               'dvu',
#               'gom',
#               'nwy',
#               'ojm',
#               'rol',
#               'roo',
#               'vig',
#               'xjp',
#               'zzh'},
#              'hoz': {'arf',
#               'bmw',
#               'dpb',
#               'dry',
#               'gio',
#               'gom',
#               'jxv',
#               'nzo',
#               'qwl',
#               'rii',
#               'roo',
#               'vig',
#               'xjp',
#               'zzh'},
#              'cvo': {'doc', 'duk', 'ihh'},
#              'rlk': {'bse', 'doc', 'duk'},
#              'mwo': {'doc', 'ihh'},
#              'tbq': {'ajb',
#               'dsj',
#               'gcl',
#               'gma',
#               'gmx',
#               'jta',
#               'lnv',
#               'pff',
#               'rxe',
#               'uow',
#               'zsg'},
#              'yxy': {'cgr',
#               'czj',
#               'dsj',
#               'gma',
#               'jta',
#               'pff',
#               'rxe',
#               'tve',
#               'uow',
#               'zgs',
#               'zsg'},
#              'odi': {'cgr',
#               'czj',
#               'gma',
#               'lnv',
#               'pto',
#               'rxe',
#               'swl',
#               'zgs',
#               'zsg'},
#              'xor': {'czj',
#               'dsj',
#               'gcl',
#               'gma',
#               'gmx',
#               'lnv',
#               'pto',
#               'rxe',
#               'swl',
#               'tve',
#               'uow'},
#              'grs': {'dfy', 'egj', 'pkq'},
#              'nco': {'egj', 'pkq'},
#              'kqp': {'dfy', 'egj', 'icl', 'pkq'},
#              'jdu': {'hhv', 'nrs', 'yqd'},
#              'qjy': {'yqd'},
#              'xlc': {'hhv', 'nrs', 'yqd'},
#              'imp': {'nrs', 'yqd'},
#              'lcc': {'nbn', 'uiv'},
#              'jre': {'nbn', 'von'},
#              'hpp': {'nbn'},
#              'fft': {'nbn', 'von'},
#              'nwz': {'bqf', 'xkq'},
#              'lie': {'bqf', 'krg', 'xkq'},
#              'nsq': {'mdd', 'zca', 'zix'},
#              'ktb': {'tys', 'zix'},
#              'hmw': {'ewb', 'jou'},
#              'fyz': {'ewb', 'jou'},
#              'ijf': {'jou', 'ykx'},
#              'wev': {'ewb', 'jou', 'ykx'},
#              'nqq': {'dec', 'qov', 'tks', 'yon'},
#              'efj': {'dec', 'drd', 'qov', 'tks', 'yon'},
#              'eub': {'dec', 'drd', 'tks', 'yon'},
#              'ekk': {'hhw', 'otl', 'yrw'},
#              'xfn': {'dpy', 'nxp', 'ufo'},
#              'oqa': {'dpy', 'nxp', 'ufo'},
#              'udo': {'ggf', 'kpl', 'tdr'},
#              'ojm': {'auz', 'hww'},
#              'yaa': {'jmj', 'uvi'},
#              'tye': {'jmj', 'uvi', 'waf'},
#              'vig': {'psw', 'xlm', 'zzd'},
#              'jxv': {'qfz', 'xlm'},
#              'hsb': {'vkg', 'xlm'},
#              'hwv': {'psw', 'xlm', 'zzd'},
#              'ysa': {'gmz', 'lyp'},
#              'xlm': {'aki', 'mpr', 'rrs', 'taq'},
#              'zzd': {'aki', 'rrs', 'taq'},
#              'psw': {'aki', 'mpr', 'rrs'},
#              'qfz': {'aki', 'mpr'},
#              'ods': {'aar', 'ayo', 'iom'},
#              'ljt': {'ayo', 'iom'},
#              'dsd': {'aar', 'ayo', 'iom'},
#              'vvf': {'cws', 'kfy', 'wnf'},
#              'zmb': {'hyl',
#               'lgg',
#               'mkb',
#               'nab',
#               'rrz',
#               'udo',
#               'uld',
#               'xfg',
#               'xtt',
#               'zgn',
#               'zqb'},
#              'bqi': {'hyl',
#               'ixd',
#               'lgg',
#               'mxm',
#               'rig',
#               'ruj',
#               'tfm',
#               'tod',
#               'udo',
#               'uld',
#               'xys',
#               'zqb'},
#              'cjt': {'hyl',
#               'ixd',
#               'lgg',
#               'nab',
#               'qqs',
#               'tfm',
#               'toc',
#               'tod',
#               'udo',
#               'uld',
#               'xfg',
#               'xys',
#               'zgn',
#               'zqb',
#               'zxh'},
#              'mmr': {'hyl',
#               'ixd',
#               'lgg',
#               'mkb',
#               'qqs',
#               'toc',
#               'udo',
#               'uld',
#               'xfg',
#               'xys',
#               'yhw',
#               'zfx',
#               'zgn'},
#              'zfx': {'ozg', 'rik'},
#              'lgg': {'ozg', 'rik', 'vfg'},
#              'zxh': {'ozg', 'rik', 'vfg'},
#              'uxk': {'awh', 'mwz', 'pnn'},
#              'oan': {'awh', 'mwz', 'pnn'},
#              'ohv': {'jdu', 'wnu', 'xlc'},
#              'jhx': {'imp', 'jdu', 'wnu'},
#              'tph': {'imp', 'jdu', 'wnu', 'xlc'},
#              'cvv': {'imp', 'jdu', 'qjy', 'xlc'},
#              'yfj': {'dgc', 'ton', 'udr', 'wdi'},
#              'nby': {'dgc', 'wdi'},
#              'nbr': {'mml', 'tpp'},
#              'flk': {'bvy', 'tpp'},
#              'jse': {'mml', 'tpp'},
#              'kqi': {'bvy', 'mml', 'tpp'},
#              'ltl': {'mml', 'tpp'},
#              'zru': {'eas'},
#              'zto': {'eas', 'eeb', 'kly', 'upy'},
#              'qxn': {'bkx', 'fbo', 'sls', 'vzg'},
#              'vch': {'bkx', 'fbo', 'kmi', 'vzg'},
#              'rjf': {'ofr', 'vhw', 'vyg'},
#              'cui': {'ofr', 'vhw', 'vyg'},
#              'cwf': {'vyg'},
#              'rgp': {'cfr', 'ldm', 'not', 'pot'},
#              'dow': {'cfr', 'ldm', 'not', 'pot'},
#              'hot': {'nvm', 'pez'},
#              'vkg': {'mpr', 'rrs'},
#              'szs': {'lyp', 'pnj'},
#              'cnt': {'lyp', 'mrk', 'pnj'},
#              'srr': {'esf', 'zhz'},
#              'kjo': {'esf', 'qnr', 'zbg', 'zhz'},
#              'aan': {'acd'},
#              'cgh': {'aan', 'fky', 'jcm', 'olo', 'xpf'},
#              'sbb': {'now', 'ovt', 'vgk'},
#              'lgs': {'itj', 'ovt', 'vgk'},
#              'pyu': {'mlv', 'now', 'ovt'},
#              'jyr': {'now', 'ovt', 'vgk'},
#              'dub': {'rsh', 'ujd', 'wmg'},
#              'lgk': {'afe',
#               'ctf',
#               'dsd',
#               'hvo',
#               'jke',
#               'kqa',
#               'lfj',
#               'ljt',
#               'ocv',
#               'qqc',
#               'ryp',
#               'ums',
#               'voe',
#               'xtr',
#               'yxx'},
#              'cca': {'afe',
#               'aiq',
#               'dsd',
#               'gil',
#               'jee',
#               'jke',
#               'kqa',
#               'ljt',
#               'ocv',
#               'ods',
#               'qqc',
#               'ums',
#               'voe',
#               'vro',
#               'vvb',
#               'wgb',
#               'xtr'},
#              'kpf': {'dec', 'qov'},
#              'ase': {'itj', 'mlv'},
#              'icp': {'bmw',
#               'btr',
#               'dry',
#               'dvu',
#               'hwv',
#               'nwy',
#               'ojm',
#               'qxl',
#               'rii',
#               'rol',
#               'roo',
#               'vig'},
#              'qxh': {'arf',
#               'ash',
#               'bmw',
#               'dpb',
#               'dry',
#               'dvu',
#               'gio',
#               'hsb',
#               'hwv',
#               'nwy',
#               'ojm',
#               'rii',
#               'rol',
#               'xjp'},
#              'wnu': {'hhv', 'nrs'},
#              'tsr': {'lrb'},
#              'yek': {'awh', 'pnn'},
#              'vzh': {'aik', 'lva'},
#              'dlu': {'aik', 'hua', 'lva'},
#              'pvm': {'aik', 'hua', 'lva'},
#              'ddr': {'aik', 'hua', 'lva'},
#              'wmh': {'bql', 'fek', 'kjz', 'qiq'},
#              'gxf': {'bql', 'kjz', 'qiq', 'tbe'},
#              'yzt': {'lkq', 'nct', 'vya', 'ypf'},
#              'jee': {'lkq', 'vya'},
#              'hvo': {'nct', 'vya', 'ypf'},
#              'oru': {'aiq',
#               'ctf',
#               'dsd',
#               'gil',
#               'hvo',
#               'jee',
#               'jke',
#               'kqa',
#               'lex',
#               'ocv',
#               'ods',
#               'qqc',
#               'ums',
#               'vro',
#               'wgb',
#               'xtr',
#               'yzt'},
#              'eas': {'bqi', 'cjt'},
#              'tbe': {'bqi', 'cjt', 'zmb'},
#              'kly': {'bqi', 'cjt', 'mmr'},
#              'qiq': {'bqi', 'cjt', 'mmr', 'zmb'},
#              'upy': {'bqi', 'cjt', 'mmr', 'zmb'},
#              'inu': {'bqi', 'cjt', 'mmr'},
#              'yrw': {'bqi', 'cjt', 'mmr', 'zmb'},
#              'bql': {'bqi', 'cjt', 'mmr', 'zmb'},
#              'otl': {'bqi', 'cjt', 'mmr', 'zmb'},
#              'bob': {'bqi', 'cjt', 'zmb'},
#              'eeb': {'bqi', 'mmr'},
#              'tsk': {'bqi', 'cjt', 'mmr'},
#              'fog': {'bqi', 'mmr'},
#              'hhw': {'bqi', 'mmr', 'zmb'},
#              'kjz': {'bqi', 'mmr', 'zmb'},
#              'cgr': {'fyz', 'hmw', 'wev'},
#              'swl': {'fyz', 'hmw', 'ijf', 'wev'},
#              'ajb': {'ijf', 'wev'},
#              'osp': {'srr', 'wij', 'yql'},
#              'rik': {'vxi', 'wdb'},
#              'krg': {'cwx', 'pom'},
#              'yil': {'hot', 'irw'},
#              'duk': {'dzs', 'qud', 'tqq'},
#              'bse': {'dzs', 'qud', 'tqq', 'unb'},
#              'ihh': {'dzs', 'qud', 'tqq', 'unb'},
#              'qnr': {'fog', 'tem'},
#              'zbg': {'bob', 'fog', 'tem'},
#              'vgk': {'hqf', 'jbq', 'jnh'},
#              'now': {'hqf', 'jbq', 'jnh'},
#              'ovt': {'hqf'},
#              'yay': {'cvo', 'mwo'},
#              'zja': {'cvo', 'mwo'},
#              'ipy': {'eax', 'msx', 'rxs'},
#              'zut': {'fgi', 'msx'},
#              'twi': {'fgi', 'msx', 'rxs'},
#              'fnd': {'eax', 'ewy', 'msx'},
#              'uld': {'fft', 'hpp', 'jre', 'lcc'},
#              'zqb': {'hpp'},
#              'nap': {'cws'},
#              'dtt': {'cws', 'wnf'},
#              'hua': {'adg', 'cjd', 'ijc'},
#              'aik': {'cjd', 'ijc', 'mdr', 'ytc'},
#              'lva': {'adg', 'cjd', 'mdr', 'ytc'},
#              'gcl': {'fyz', 'hmw', 'uuj'},
#              'kns': {'dac', 'uwo', 'waf'},
#              'onr': {'dac', 'uwo'},
#              'wxe': {'dac', 'uwo'},
#              'the': {'ffh'},
#              'qir': {'ffh', 'tsk', 'yrw'},
#              'euo': {'aiq',
#               'ctf',
#               'dsd',
#               'gil',
#               'jee',
#               'jke',
#               'kqa',
#               'lex',
#               'lfj',
#               'ocv',
#               'qqc',
#               'voe',
#               'vro',
#               'wgb',
#               'xtr',
#               'yzt'},
#              'qrc': {'aiq',
#               'ctf',
#               'dsd',
#               'gil',
#               'hvo',
#               'jee',
#               'jke',
#               'kqa',
#               'lex',
#               'lfj',
#               'ljt',
#               'ocv',
#               'ryp',
#               'ums',
#               'voe',
#               'vro',
#               'wgb',
#               'xtr',
#               'yzt'},
#              'jke': {'hva', 'lkq', 'nct'},
#              'hqq': {'dtb',
#               'gle',
#               'jfw',
#               'kzv',
#               'nqq',
#               'onr',
#               'rhm',
#               'svx',
#               'yqt'},
#              'zsg': {'dmn', 'hro'},
#              'jta': {'hro', 'zro'},
#              'czj': {'dmn', 'fss', 'hro'},
#              'ybp': {'uhi', 'wmg'},
#              'cki': {'uhi', 'wmg'},
#              'gsj': {'uya'},
#              'sse': {'irk', 'uya'},
#              'aay': {'ibc', 'uya'},
#              'mii': {'ibc', 'uya'},
#              'zhz': {'bob', 'fog'},
#              'esf': {'bob'},
#              'wns': {'ibt', 'iwp'},
#              'acw': {'ibt'},
#              'nhy': {'ibt', 'iwp', 'xbq'},
#              'pdw': {'ibt', 'iwp'},
#              'hwz': {'cfr', 'ebr', 'pot'},
#              'pgb': {'cfr', 'ldm', 'pot'},
#              'hux': {'cjj', 'ymz'},
#              'itm': {'cjj', 'omy', 'uul', 'ymz'},
#              'fss': {'pgo', 'tlh', 'wpr'},
#              'dmn': {'wpr'},
#              'hro': {'pgo', 'tlh', 'wpr'},
#              'zro': {'tlh', 'wpr'},
#              'vib': {'nhy', 'wns'},
#              'jqz': {'acw', 'nhy', 'pdw'},
#              'ysb': {'acw', 'fti', 'nhy', 'pdw', 'wns'},
#              'utf': {'nhy', 'wns'},
#              'nek': {'hoz', 'hvb', 'icp'},
#              'icl': {'hoz', 'hvb', 'icp'},
#              'wal': {'hoz', 'icp'},
#              'oou': {'icp', 'qxh'},
#              'bvy': {'hoz', 'icp'},
#              'xfk': {'hoz', 'hvb', 'icp'},
#              'dpy': {'hvb', 'icp'},
#              'bsp': {'hoz', 'icp', 'qxh'},
#              'eyn': {'icp', 'qxh'},
#              'nxp': {'hoz', 'icp'},
#              'nth': {'icp', 'qxh'},
#              'hap': {'hoz', 'icp'},
#              'fnc': {'hoz', 'icp'},
#              'xce': {'hoz', 'icp', 'qxh'},
#              'qcz': {'hoz', 'icp'},
#              'pkq': {'hoz', 'icp'},
#              'ufo': {'hoz', 'icp', 'qxh'},
#              'tpp': {'hoz', 'icp', 'qxh'},
#              'egj': {'hoz', 'icp'},
#              'mml': {'hoz', 'icp'},
#              'dfy': {'hvb', 'icp'},
#              'inr': {'bqf'},
#              'ryp': {'bti', 'kec'},
#              'yxx': {'bti', 'kec', 'ulu'},
#              'qqc': {'bti', 'kec', 'ulu'},
#              'kqa': {'bti', 'kec', 'ulu'},
#              'hva': {'flk', 'jse', 'kqi', 'nbr'},
#              'ypf': {'jse', 'ltl'},
#              'lkq': {'flk', 'jse', 'kqi', 'nbr'},
#              'vya': {'flk', 'jse', 'kqi', 'nbr'},
#              'nct': {'flk', 'jse'},
#              'zgn': {'szs', 'ysa'},
#              'ijc': {'apo', 'pxs', 'you'},
#              'iwp': {'hqq', 'pxs', 'you'},
#              'mdr': {'apo', 'hqq', 'pxs', 'you'},
#              'cjd': {'apo', 'you'},
#              'yoa': {'pxs', 'you'},
#              'fek': {'cjt', 'mmr'},
#              'tem': {'cjt', 'mmr', 'zmb'},
#              'ffh': {'cjt', 'mmr'},
#              'bhj': {'cjt', 'mmr', 'zmb'},
#              'ajh': {'bjx', 'yic'},
#              'acd': {'yic'},
#              'dhw': {'yic'},
#              'hhq': {'tgc'},
#              'gil': {'cki'},
#              'wgb': {'cki', 'dub', 'ybp'},
#              'voe': {'cki', 'dub', 'ybp'},
#              'ctf': {'cki', 'ybp'},
#              'kpl': {'ktb', 'nsq', 'zfb'},
#              'tdr': {'ktb', 'zfb'},
#              'twx': {'ktb', 'zfb'},
#              'mia': {'pdw', 'wns'},
#              'dac': {'iqu', 'vkn', 'wdr'},
#              'uwo': {'iqu', 'vkn', 'wdr'},
#              'uvi': {'bxi', 'iqu'},
#              'waf': {'iqu'},
#              'wij': {'esf'},
#              'egf': {'icg', 'pvm'},
#              'nja': {'ddr', 'dlu', 'icg'},
#              'xcs': {'ddr', 'dlu', 'icg', 'pvm'},
#              'bfv': {'ddr', 'icg'},
#              'kia': {'pyd', 'qxn', 'vch', 'ztw'},
#              'von': {'odi', 'tbq', 'xor', 'yxy'},
#              'pot': {'odi', 'tbq', 'yxy'},
#              'zca': {'odi', 'tbq'},
#              'ldm': {'odi'},
#              'zix': {'odi', 'tbq', 'xor'},
#              'iuo': {'bbm', 'odi', 'tbq'},
#              'nbn': {'odi', 'tbq', 'xor'},
#              'vea': {'odi', 'tbq', 'xor'},
#              'qtw': {'bbm', 'odi', 'xor'},
#              'lyp': {'odi', 'tbq', 'xor'},
#              'ebr': {'odi', 'tbq', 'xor'},
#              'hbf': {'bbm', 'odi', 'tbq'},
#              'uiv': {'odi', 'xor'},
#              'cfr': {'bbm', 'odi', 'tbq', 'xor', 'yxy'},
#              'gmz': {'bbm', 'odi', 'yxy'},
#              'byn': {'odi', 'tbq', 'xor'},
#              'ehh': {'odi', 'tbq', 'xor'},
#              'mrk': {'odi', 'tbq', 'xor'},
#              'not': {'bbm', 'odi', 'tbq', 'xor'},
#              'pnj': {'odi', 'tbq', 'xor'},
#              'ghx': {'odi', 'xor'},
#              'ltf': {'kjo', 'srr'},
#              'kkr': {'kjo', 'srr'},
#              'jmj': {'vkn', 'wdr'},
#              'iih': {'byi', 'oan', 'uxk', 'yek'},
#              'luy': {'byi', 'oan', 'uxk', 'yek'},
#              'mei': {'uxk', 'yek'},
#              'obi': {'cke', 'pln', 'wjh'},
#              'pfu': {'cke', 'pln', 'wjh'},
#              'ist': {'bip', 'qtw'},
#              'fhx': {'rjp', 'rno'},
#              'imo': {'rjp', 'rno', 'tdi'},
#              'pyd': {'bkx', 'fbo', 'kmi', 'sls'},
#              'ztw': {'bkx', 'fbo', 'sls'},
#              'dxi': {'bhg', 'iyp', 'qea'},
#              'wef': {'bhg', 'iyp', 'qea'},
#              'mpn': {'iyp'},
#              'peu': {'dtt', 'plm'},
#              'sce': {'dtt', 'nap', 'plm'},
#              'ido': {'dtt', 'vvf'},
#              'alv': {'dtt', 'nap', 'plm', 'vvf'},
#              'doc': {'qud'},
#              'irw': {'nvm', 'pwf', 'qbu'},
#              'xca': {'nvm', 'pwf', 'qbu'},
#              'nzo': {'zto'},
#              'ash': {'bcj', 'zru', 'zto'},
#              'gom': {'zru', 'zto'},
#              'vfg': {'ist', 'vxi'},
#              'eax': {'aay', 'gsj', 'mii', 'sse'},
#              'fgi': {'aay', 'gsj', 'mii'},
#              'rxs': {'gsj', 'mii', 'sse'},
#              'tys': {'bbm', 'tbq', 'xor', 'yxy'},
#              'wjp': {'ghx', 'iuo'},
#              'vyg': {'euo', 'oru', 'qrc'},
#              'jbn': {'cca', 'lgk', 'oru'},
#              'yap': {'cca', 'oru', 'qrc'},
#              'cfw': {'cca', 'oru'},
#              'qbg': {'oru', 'qrc'},
#              'lrb': {'cca', 'oru', 'qrc'},
#              'dju': {'cca', 'oru', 'qrc'},
#              'dzk': {'cca', 'euo', 'lgk', 'oru'},
#              'yic': {'cca', 'oru', 'qrc'},
#              'vhw': {'lgk', 'oru', 'qrc'},
#              'xgh': {'cca', 'oru', 'qrc'},
#              'ofr': {'cca', 'oru', 'qrc'},
#              'dec': {'agf', 'cui', 'cwf', 'rjf'},
#              'drd': {'agf', 'cui', 'cwf'},
#              'ujd': {'dvj', 'nhp', 'shq'},
#              'rsh': {'dvj', 'kzb'},
#              'cjj': {'hli', 'snw'},
#              'uul': {'dzk', 'hli', 'snw'},
#              'omy': {'dzk', 'hli', 'snw'},
#              'btr': {'ltf', 'osp'},
#              'xjp': {'kkr', 'osp'},
#              'arf': {'ltf', 'osp'},
#              'xtt': {'kpl', 'twx'},
#              'tfm': {'kpl', 'twx'},
#              'wdr': {'xgh', 'yap'},
#              'bxi': {'xgh', 'yap'},
#              'iqu': {'xgh', 'yap'},
#              'rhm': {'aan', 'jcm', 'olo', 'xpf'},
#              'rol': {'hzg'},
#              'bcj': {'eeb', 'upy'},
#              'awh': {'ajs', 'hhg', 'kji'},
#              'ibc': {'ajs', 'hhg'},
#              'xts': {'snw', 'zbx'},
#              'jbd': {'cvo', 'vuc'},
#              'hqz': {'vuc', 'zhh'},
#              'ewy': {'aay', 'gsj', 'sse'},
#              'msx': {'aay', 'sse'},
#              'agf': {'cfw', 'ofr', 'pjp'},
#              'nwy': {'kkr', 'ltf'},
#              'dzs': {'dxi', 'vdc', 'wef'},
#              'tqq': {'dxi', 'mpn', 'wef'},
#              'qud': {'dxi', 'vdc'},
#              'unb': {'dxi', 'vdc', 'wef'},
#              'mdd': {'bbm', 'tbq'},
#              'hyl': {'kvd', 'wjp'},
#              'nab': {'kvd', 'wjp'},
#              'qqs': {'kvd', 'ttx', 'wjp'},
#              'rig': {'kvd', 'ttx', 'wjp'},
#              'lex': {'bti'},
#              'pff': {'fnd', 'twi', 'zut'},
#              'gmx': {'fnd', 'ipy', 'zut'},
#              'lnv': {'ipy', 'twi', 'zut'},
#              'uuj': {'ykx'},
#              'aar': {'nco'},
#              'ayo': {'kqp', 'nco'},
#              'yql': {'qnr', 'zbg'},
#              'djk': {'jcm', 'olo', 'xpf'},
#              'qov': {'cui', 'cwf', 'rjf'},
#              'tks': {'cui', 'cwf'},
#              'yon': {'cwf'},
#              'uco': {'oqa', 'uyo', 'xfn'},
#              'hfl': {'oqa', 'uyo'},
#              'wmg': {'kzb'},
#              'vzg': {'apo', 'hqq', 'pxs'},
#              'sls': {'apo', 'hqq', 'pxs'},
#              'adg': {'apo'},
#              'bhg': {'apo', 'pxs'},
#              'qea': {'apo', 'pxs'},
#              'llk': {'apo', 'pxs'},
#              'cwx': {'apo', 'hqq'},
#              'iyp': {'apo', 'hqq'},
#              'pom': {'apo', 'pxs'},
#              'kmi': {'apo'},
#              'pto': {'jco', 'mhf'},
#              'tve': {'dmg', 'jco', 'mhf'},
#              'rxe': {'dmg', 'mhf'},
#              'tqn': {'hhw', 'yrw'},
#              'bzb': {'hhw'},
#              'dmg': {'iih', 'luy', 'mei', 'vvq'},
#              'jco': {'luy', 'mei'},
#              'ldl': {'fek', 'kjz', 'qiq', 'tbe'},
#              'sai': {'fek', 'kjz', 'qiq', 'tbe'},
#              'olo': {'ajh'},
#              'fky': {'ajh', 'dhw', 'tsr'},
#              'xpf': {'ajh', 'dhw', 'tsr'},
#              'jcm': {'ajh', 'tsr'},
#              'dsj': {'fnd', 'ipy', 'twi'},
#              'wdi': {'bfv', 'egf', 'nja', 'xcs'},
#              'udr': {'bfv', 'egf'},
#              'ocv': {'onw', 'pmo', 'syt'},
#              'xtr': {'dqh', 'onw', 'pmo', 'qop'},
#              'vow': {'eyn', 'qcz'},
#              'yvx': {'eyn', 'xfk'},
#              'wll': {'eyn', 'qcz', 'xfk'},
#              'ceo': {'sza', 'udr', 'wdi'},
#              'mlv': {'jbq', 'jnh'},
#              'bqf': {'llk', 'pom'},
#              'wdo': {'xts', 'ymz'},
#              'elm': {'pgo'},
#              'dtb': {'wdo'},
#              'arm': {'frs'},
#              'boq': {'fhx', 'frs', 'imo'},
#              'vkn': {'dju', 'yap'},
#              'ruj': {'dow', 'pgb'},
#              'mkb': {'dow', 'hwz', 'pgb'},
#              'mxm': {'dow', 'pgb', 'rgp'},
#              'ixd': {'dow', 'hwz', 'pgb', 'wyq'},
#              'vni': {'ase', 'jyr', 'lgs', 'pyu'},
#              'uow': {'ase', 'jyr', 'lgs'},
#              'lpr': {'imp'},
#              'toc': {'jre', 'lcc'},
#              'mpr': {'ekk', 'qir'},
#              'rrs': {'bzb', 'ekk', 'qir', 'tqn'},
#              'yhw': {'hwz', 'rgp'},
#              'ttx': {'ehh', 'ghx'},
#              'orh': {'fek'},
#              'zhh': {'duk', 'ihh'},
#              'syt': {'idw', 'qac', 'szj'},
#              'pmo': {'idw', 'qac', 'szj'},
#              'qop': {'qac', 'szj'},
#              'dqh': {'idw', 'qac', 'szj'},
#              'onw': {'idw', 'qac', 'szj'},
#              'icg': {'hua', 'lva'},
#              'bjx': {'cca', 'lgk'},
#              'gma': {'elm'},
#              'egz': {'qcz', 'xfk'},
#              'wyq': {'ebr', 'ldm'},
#              'yqd': {'jqz', 'mia', 'utf', 'vib', 'ysb'},
#              'nrs': {'jqz', 'mia', 'ysb'},
#              'xfg': {'fft', 'lcc'},
#              'cke': {'aqf', 'wux'},
#              'wjh': {'aqf', 'gue', 'wux'},
#              'tgc': {'gue', 'wux'},
#              'pln': {'gue', 'wux'},
#              'idw': {'hap', 'nth', 'oou', 'wal'},
#              'szj': {'hap', 'nth', 'wal'},
#              'rjp': {'byx', 'kia', 'uiq'},
#              'tdi': {'byx', 'kia', 'uiq'},
#              'gio': {'ldl', 'orh', 'sai'},
#              'bmw': {'gxf', 'ldl', 'orh', 'sai', 'wmh'},
#              'dvu': {'ldl', 'orh', 'sai', 'wmh'},
#              'rrz': {'cnt', 'ysa'},
#              'tod': {'ysa'},
#              'lfj': {'wll', 'yvx'},
#              'afe': {'egz', 'yvx'},
#              'vro': {'egz', 'yvx'},
#              'aiq': {'vow', 'yvx'},
#              'ums': {'vow', 'yvx'},
#              'byi': {'pnn'},
#              'uyo': {'ufo'},
#              'iic': {'fhx', 'imo'},
#              'fde': {'nap', 'vvf'},
#              'pnn': {'hhg', 'kji'},
#              'tmv': {'cca', 'qrc'},
#              'snw': {'cca', 'euo', 'qrc'},
#              'hli': {'cca', 'qrc'},
#              'pjp': {'qrc'},
#              'fbo': {'hqq'},
#              'xbq': {'hqq', 'pxs'},
#              'ibt': {'hqq', 'pxs'},
#              'vvq': {'byi', 'uxk'},
#              'fti': {'iwp'},
#              'mhf': {'mei', 'vvq', 'wrc'},
#              'ggf': {'nsq'},
#              'kzb': {'nek'},
#              'dpb': {'psw'},
#              'hhv': {'ysb'},
#              'ami': {'imo', 'ndx'},
#              'qac': {'wal', 'xce'},
#              'aqf': {'jbn', 'tmv'},
#              'kvd': {'ghx', 'vea'},
#              'qxl': {'orh', 'wmh'},
#              'zzh': {'orh', 'sai', 'wmh'},
#              'vys': {'itm'},
#              'xwt': {'itm', 'vuf'},
#              'zbx': {'euo'},
#              'qlb': {'cjt', 'zmb'},
#              'rii': {'bcj'},
#              'ton': {'nja', 'tkr'},
#              'dgc': {'bfv', 'nja', 'tkr'},
#              'vdc': {'qea'},
#              'frs': {'tdi'},
#              'ndx': {'rjp', 'tdi'},
#              'wrc': {'byi', 'oan'},
#              'wpr': {'kji', 'zdb'},
#              'byx': {'pyd'},
#              'gle': {'hhq', 'obi'},
#              'fhf': {'obi', 'pfu'},
#              'jyj': {'obi', 'pfu'},
#              'kzv': {'obi'},
#              'sza': {'bfv', 'tkr'},
#              'ajs': {'svr'},
#              'zdb': {'svr'},
#              'kji': {'svr'},
#              'ygp': {'svr'},
#              'hhg': {'svr'},
#              'tkr': {'ddr', 'vzh'},
#              'jfw': {'pfu'},
#              'xys': {'ttx'},
#              'xkq': {'yoa'},
#              'wnf': {'inr'},
#              'rdq': {'inr', 'lie', 'nwz'},
#              'svx': {'olo', 'xpf'},
#              'ozg': {'ist'},
#              'qwl': {'hww'},
#              'ftg': {'imo'},
#              'bip': {'xor'},
#              'itj': {'kxa'},
#              'hcx': {'uyo'},
#              'gue': {'qbg', 'tmv'},
#              'wux': {'qbg', 'tmv'},
#              'cws': {'lie', 'nwz'},
#              'kfy': {'lie', 'nwz'},
#              'vuf': {'ymz'},
#              'ryh': {'ctt', 'hot'},
#              'uiq': {'vch', 'ztw'},
#              'ytc': {'pxs'},
#              'bkx': {'pxs'},
#              'rno': {'kia'},
#              'uhi': {'ule'},
#              'ctt': {'nvm', 'pwf'},
#              'vuc': {'ihh'},
#              'ymz': {'snw'},
#              'vvb': {'onw', 'qop'},
#              'zfb': {'tys'}})

# %%
results = []
start = 'you'
visited = set()

def dfs(node, path, visited):
    if node == 'out':
        results.append(path + [node])
        return

    for next_item in parsed_inputs.get(node, []):
        if next_item in visited:
            continue
        dfs(next_item, path + [node], visited | {next_item})

@lru_cache(maxsize=None)
def dp(node, visited_frozenset):
    if node == 'out':
        return [[node]]
    paths = []
    for next_item in parsed_inputs.get(node, []):
        if next_item in visited_frozenset:
            continue
        for subpath in dp(next_item, visited_frozenset | frozenset([next_item])):
            paths.append([node] + subpath)
    return paths

all_paths = []
for neighbor in parsed_inputs[start]:
    for path in dp(neighbor, frozenset([start, neighbor])):
        all_paths.append([start] + path)
results = all_paths

# %%
results
# Out:
# [['you', 'ijc', 'hua', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'icg', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'hua', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'vzh', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'vzh', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'vzh', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'vzh', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'ijc', 'aik', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'ysb', 'hhv', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'wns', 'mia', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'wns', 'vib', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'wns', 'utf', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'fti', 'ysb', 'hhv', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'nhy', 'vib', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'nhy', 'jqz', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'ysb', 'hhv', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'nhy', 'utf', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'ysb', 'hhv', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'pdw', 'jqz', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'qjy', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'yqd', 'imp', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'jdu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'jdu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'jdu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'jdu', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'wnu', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'wnu', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'wnu', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'xlc', 'ohv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'xlc', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'xlc', 'cvv', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'imp', 'tph', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'imp', 'jhx', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'imp', 'lpr', 'out'],
#  ['you', 'iwp', 'pdw', 'mia', 'nrs', 'imp', 'cvv', 'out'],
#  ['you', 'mdr', 'aik', 'vzh', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'vzh', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'vzh', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'vzh', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'aik', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'icg', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'vzh', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'vzh', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'vzh', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'vzh', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'mdr', 'lva', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'icg', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'hua', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'vzh', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'vzh', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'vzh', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'vzh', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'aik', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'dlu', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'ddr', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'nja', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'nja', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'nja', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'nja', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'nja', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'nja', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'icg', 'bfv', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'vzh', 'tkr', 'ton', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'vzh', 'tkr', 'dgc', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'vzh', 'tkr', 'dgc', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'vzh', 'tkr', 'sza', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'egf', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'egf', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'egf', 'wdi', 'nby', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'egf', 'udr', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'egf', 'udr', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'xcs', 'wdi', 'ceo', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'xcs', 'wdi', 'yfj', 'out'],
#  ['you', 'cjd', 'lva', 'pvm', 'xcs', 'wdi', 'nby', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'vvf', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'vvf', 'ido', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'vvf', 'fde', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'plm', 'peu', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'plm', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'plm', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'nap', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'nap', 'fde', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'nap', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'dtt', 'peu', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'dtt', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'dtt', 'ido', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'cws', 'dtt', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'rdq', 'plm', 'peu', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'rdq', 'plm', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'rdq', 'plm', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'kfy', 'vvf', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'kfy', 'vvf', 'ido', 'out'],
#  ['you', 'yoa', 'xkq', 'nwz', 'kfy', 'vvf', 'fde', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'vvf', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'vvf', 'ido', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'vvf', 'fde', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'plm', 'peu', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'plm', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'plm', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'nap', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'nap', 'fde', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'nap', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'dtt', 'peu', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'dtt', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'dtt', 'ido', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'cws', 'dtt', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'rdq', 'plm', 'peu', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'rdq', 'plm', 'sce', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'rdq', 'plm', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'kfy', 'vvf', 'alv', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'kfy', 'vvf', 'ido', 'out'],
#  ['you', 'yoa', 'xkq', 'lie', 'kfy', 'vvf', 'fde', 'out']]

# %%
len(results)
# Out:
# 708
